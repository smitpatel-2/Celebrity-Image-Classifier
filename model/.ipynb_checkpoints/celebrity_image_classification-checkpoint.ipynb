# %% [markdown]
# <h2 align='center'>Celebrity Image Classification<h2>

# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# <h3>Face and Eyes Detection</h3>

# %% [markdown]
# - The first step is to detect faces from an image.
# - Once face is detected, detect eyes, if two eyes are detected then only keep that image otherwise discard it.

# %%
img = cv2.imread('./test_images/virat1.jpg')
img.shape
# Out:
# (192, 192, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (192, 192)

# %%
gray
# Out:
# array([[254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        ...,
#        [158, 150, 142, ..., 124, 124, 124],
#        [155, 150, 142, ..., 123, 123, 122],
#        [143, 143, 143, ..., 123, 122, 122]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[44, 36, 98, 98]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (44, 36, 98, 98)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %% [markdown]
# ### Crop the facial region of the image

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (98, 98, 3)

# %% [markdown]
# ### Use wavelet transform as a feature for traning model

# %% [markdown]
# - In wavelet transformed image, you can see edges clearly and that can give us clues on various facial features such as eyes, nose, lips etc

# %% [markdown]
# ### Wavelet transform

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %% [markdown]
# You can see above a wavelet transformed image that gives clues on facial features such as eyes, nose, lips etc. This along with raw pixel image can be used as an input for our classifier

# %% [markdown]
# ### Load image, detect face. If eyes >=2, then save and crop the face region

# %% [markdown]
# Python function that can take input image and returns cropped image (if face and eyes >=2 are detected)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    #k = cv2.waitKey(600)
    if img is not None:
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)
        for (x,y,w,h) in faces:
            roi_gray = gray[y:y+h, x:x+w]
            roi_color = img[y:y+h, x:x+w]
            eyes = eye_cascade.detectMultiScale(roi_gray)
            if len(eyes) >= 2:
                return roi_color

# %%
original_image = cv2.imread('./test_images/virat1.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/virat1.jpg')
plt.imshow(cropped_image)

# %% [markdown]
# In below image face is not very clear and it doesn't have two eyes clearly visible

# %%
org_image_obstructed = cv2.imread('./test_images/virat2.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images/virat2.jpg')
cropped_image_no_2_eyes

# %% [markdown]
# Above cropped_image_no_2_eyes is None which means we should ignore this image and we will not use such image for model training

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/akshay_kumar',
#  './dataset/alia_bhatt',
#  './dataset/amitabh_bachchan',
#  './dataset/cropped',
#  './dataset/deepika_padukone',
#  './dataset/kiara_advani',
#  './dataset/m_s_dhoni',
#  './dataset/p_v_sindhu',
#  './dataset/ranveer_singh',
#  './dataset/rashmika_mandana',
#  './dataset/virat_kohli']

# %% [markdown]
# #### Go through all images in dataset folder and create cropped images for them. There will be cropped folder inside dataset folder after you run this code

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/akshay_kumar
# Generating cropped images in folder:  ./dataset/cropped/alia_bhatt
# Generating cropped images in folder:  ./dataset/cropped/amitabh_bachchan
# Generating cropped images in folder:  ./dataset/cropped/deepika_padukone
# Generating cropped images in folder:  ./dataset/cropped/kiara_advani
# Generating cropped images in folder:  ./dataset/cropped/m_s_dhoni
# Generating cropped images in folder:  ./dataset/cropped/p_v_sindhu
# Generating cropped images in folder:  ./dataset/cropped/ranveer_singh
# Generating cropped images in folder:  ./dataset/cropped/rashmika_mandana
# Generating cropped images in folder:  ./dataset/cropped/virat_kohli

# %% [markdown]
# ### Now you should have cropped folder under datasets folder that contains cropped images

# %% [markdown]
# ### Manually examine cropped folder and delete any unwanted images

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'akshay_kumar': ['./dataset/cropped/akshay_kumar\\akshay_kumar1.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar100.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar101.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar102.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar103.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar104.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar105.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar108.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar11.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar110.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar111.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar112.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar114.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar115.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar117.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar118.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar119.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar120.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar122.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar123.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar124.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar125.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar127.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar128.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar129.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar130.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar131.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar132.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar133.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar134.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar135.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar138.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar139.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar14.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar141.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar142.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar143.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar144.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar145.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar146.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar149.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar15.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar150.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar151.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar152.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar153.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar155.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar156.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar157.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar158.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar160.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar161.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar162.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar166.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar169.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar170.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar173.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar174.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar175.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar176.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar181.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar183.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar186.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar187.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar188.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar189.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar190.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar193.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar195.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar196.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar197.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar198.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar199.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar2.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar201.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar203.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar205.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar206.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar207.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar208.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar21.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar210.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar211.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar213.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar214.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar215.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar216.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar218.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar22.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar222.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar223.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar224.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar226.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar229.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar23.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar237.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar238.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar239.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar24.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar240.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar241.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar242.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar243.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar246.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar248.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar249.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar25.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar250.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar251.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar252.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar253.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar254.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar255.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar257.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar258.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar26.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar261.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar262.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar264.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar266.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar267.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar269.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar27.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar270.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar271.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar273.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar276.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar279.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar28.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar280.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar282.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar284.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar286.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar287.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar288.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar29.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar290.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar292.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar297.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar3.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar31.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar32.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar33.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar34.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar35.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar36.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar37.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar39.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar4.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar40.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar41.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar43.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar44.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar45.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar46.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar47.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar48.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar49.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar52.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar53.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar54.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar56.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar58.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar59.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar6.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar60.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar63.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar65.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar66.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar68.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar69.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar70.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar71.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar72.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar73.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar74.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar75.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar76.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar79.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar8.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar80.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar81.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar82.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar84.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar86.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar88.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar89.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar91.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar92.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar93.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar94.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar95.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar97.png',
#   './dataset/cropped/akshay_kumar\\akshay_kumar98.png'],
#  'alia_bhatt': ['./dataset/cropped/alia_bhatt\\alia_bhatt1.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt10.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt100.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt101.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt102.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt104.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt105.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt107.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt108.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt109.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt11.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt111.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt112.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt113.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt114.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt115.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt116.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt117.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt118.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt119.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt12.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt120.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt121.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt122.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt123.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt124.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt125.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt126.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt127.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt128.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt129.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt13.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt130.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt131.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt132.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt133.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt134.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt135.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt136.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt139.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt14.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt141.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt142.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt143.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt144.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt145.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt146.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt147.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt148.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt149.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt150.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt151.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt153.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt154.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt156.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt157.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt158.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt159.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt16.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt160.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt161.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt162.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt163.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt165.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt168.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt169.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt17.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt170.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt171.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt172.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt173.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt174.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt175.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt176.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt177.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt178.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt179.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt18.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt180.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt183.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt185.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt186.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt188.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt189.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt19.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt190.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt191.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt192.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt193.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt194.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt195.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt196.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt197.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt198.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt199.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt2.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt20.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt200.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt201.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt202.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt203.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt204.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt205.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt206.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt207.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt208.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt209.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt21.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt211.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt212.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt214.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt215.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt216.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt217.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt218.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt219.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt220.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt221.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt222.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt223.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt225.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt226.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt227.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt228.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt229.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt23.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt231.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt232.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt233.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt234.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt235.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt236.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt237.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt238.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt239.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt24.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt240.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt241.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt242.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt243.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt244.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt245.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt246.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt247.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt249.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt25.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt250.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt251.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt252.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt253.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt254.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt255.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt256.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt257.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt258.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt259.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt260.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt262.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt263.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt264.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt265.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt266.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt267.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt268.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt269.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt27.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt271.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt273.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt276.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt278.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt28.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt280.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt282.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt284.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt285.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt286.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt287.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt288.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt289.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt29.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt290.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt291.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt295.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt296.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt297.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt298.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt299.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt3.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt30.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt301.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt302.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt303.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt305.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt306.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt307.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt308.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt31.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt310.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt311.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt312.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt313.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt314.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt315.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt316.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt317.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt318.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt319.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt32.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt320.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt321.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt323.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt324.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt325.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt326.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt327.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt33.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt330.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt333.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt334.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt335.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt336.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt338.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt34.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt340.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt341.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt342.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt343.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt344.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt345.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt346.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt347.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt348.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt349.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt35.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt350.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt351.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt352.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt354.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt356.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt359.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt360.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt361.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt363.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt365.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt366.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt367.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt368.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt37.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt370.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt371.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt372.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt373.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt374.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt375.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt376.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt377.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt378.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt379.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt38.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt380.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt383.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt384.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt385.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt388.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt39.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt390.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt392.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt393.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt394.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt396.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt397.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt398.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt399.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt4.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt40.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt400.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt401.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt402.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt403.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt405.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt406.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt407.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt408.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt409.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt410.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt411.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt413.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt414.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt415.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt416.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt418.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt42.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt420.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt421.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt422.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt423.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt424.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt425.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt426.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt43.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt44.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt45.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt46.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt47.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt48.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt49.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt5.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt50.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt51.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt52.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt53.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt55.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt56.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt57.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt59.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt6.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt60.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt61.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt62.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt63.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt64.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt66.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt67.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt68.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt69.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt7.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt70.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt71.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt72.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt74.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt75.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt76.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt78.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt8.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt80.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt81.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt82.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt83.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt84.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt85.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt86.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt87.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt88.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt89.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt9.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt90.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt91.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt92.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt93.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt94.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt95.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt97.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt98.png',
#   './dataset/cropped/alia_bhatt\\alia_bhatt99.png'],
#  'amitabh_bachchan': ['./dataset/cropped/amitabh_bachchan\\amitabh_bachchan1.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan10.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan100.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan101.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan102.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan104.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan106.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan107.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan108.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan109.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan11.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan110.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan111.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan112.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan118.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan119.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan12.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan125.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan126.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan13.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan130.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan135.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan137.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan139.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan140.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan141.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan142.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan143.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan144.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan146.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan149.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan151.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan152.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan153.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan154.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan155.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan156.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan157.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan159.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan161.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan162.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan164.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan165.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan166.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan168.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan169.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan171.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan172.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan18.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan181.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan183.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan184.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan185.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan186.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan187.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan189.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan19.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan190.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan191.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan192.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan193.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan194.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan195.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan199.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan2.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan201.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan203.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan205.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan206.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan21.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan217.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan219.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan22.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan222.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan223.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan225.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan229.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan236.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan239.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan241.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan242.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan243.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan244.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan250.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan251.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan252.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan26.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan27.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan28.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan29.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan30.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan32.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan34.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan35.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan37.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan38.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan39.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan4.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan41.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan43.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan44.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan45.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan53.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan54.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan55.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan59.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan61.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan62.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan63.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan65.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan66.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan67.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan7.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan70.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan73.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan74.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan75.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan76.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan79.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan8.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan80.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan81.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan82.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan83.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan84.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan85.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan88.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan89.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan9.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan90.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan91.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan92.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan94.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan95.png',
#   './dataset/cropped/amitabh_bachchan\\amitabh_bachchan98.png'],
#  'deepika_padukone': ['./dataset/cropped/deepika_padukone\\deepika_padukone1.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone10.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone100.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone101.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone103.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone104.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone105.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone106.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone107.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone108.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone109.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone11.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone111.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone112.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone113.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone114.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone115.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone117.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone119.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone12.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone121.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone122.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone123.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone124.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone126.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone127.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone129.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone13.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone130.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone131.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone132.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone133.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone135.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone136.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone137.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone139.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone14.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone140.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone141.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone142.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone143.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone145.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone146.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone147.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone148.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone149.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone15.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone150.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone151.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone152.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone153.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone154.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone155.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone156.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone157.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone158.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone159.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone16.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone160.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone161.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone162.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone163.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone164.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone165.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone169.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone17.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone170.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone171.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone173.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone174.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone175.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone176.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone177.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone178.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone179.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone18.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone180.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone181.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone182.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone183.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone184.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone185.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone186.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone187.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone188.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone189.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone19.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone190.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone191.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone192.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone193.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone194.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone195.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone196.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone197.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone198.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone199.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone2.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone20.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone200.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone203.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone204.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone205.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone207.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone208.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone209.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone21.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone210.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone211.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone212.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone214.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone215.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone216.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone217.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone218.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone219.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone22.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone220.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone221.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone222.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone223.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone224.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone225.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone226.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone227.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone228.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone229.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone23.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone230.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone231.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone233.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone234.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone236.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone237.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone238.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone239.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone24.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone240.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone241.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone242.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone243.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone244.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone245.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone246.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone247.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone248.png',
#   './dataset/cropped/deepika_padukone\\deepika_padukone249.png',
# ...
#   './dataset/cropped/virat_kohli\\virat_kohli286.png',
#   './dataset/cropped/virat_kohli\\virat_kohli287.png',
#   './dataset/cropped/virat_kohli\\virat_kohli288.png',
#   './dataset/cropped/virat_kohli\\virat_kohli290.png',
#   './dataset/cropped/virat_kohli\\virat_kohli291.png',
#   './dataset/cropped/virat_kohli\\virat_kohli292.png',
#   './dataset/cropped/virat_kohli\\virat_kohli293.png',
#   './dataset/cropped/virat_kohli\\virat_kohli294.png',
#   './dataset/cropped/virat_kohli\\virat_kohli295.png',
#   './dataset/cropped/virat_kohli\\virat_kohli296.png',
#   './dataset/cropped/virat_kohli\\virat_kohli297.png',
#   './dataset/cropped/virat_kohli\\virat_kohli298.png',
#   './dataset/cropped/virat_kohli\\virat_kohli299.png',
#   './dataset/cropped/virat_kohli\\virat_kohli3.png',
#   './dataset/cropped/virat_kohli\\virat_kohli30.png',
#   './dataset/cropped/virat_kohli\\virat_kohli300.png',
#   './dataset/cropped/virat_kohli\\virat_kohli301.png',
#   './dataset/cropped/virat_kohli\\virat_kohli302.png',
#   './dataset/cropped/virat_kohli\\virat_kohli304.png',
#   './dataset/cropped/virat_kohli\\virat_kohli305.png',
#   './dataset/cropped/virat_kohli\\virat_kohli306.png',
#   './dataset/cropped/virat_kohli\\virat_kohli307.png',
#   './dataset/cropped/virat_kohli\\virat_kohli308.png',
#   './dataset/cropped/virat_kohli\\virat_kohli31.png',
#   './dataset/cropped/virat_kohli\\virat_kohli310.png',
#   './dataset/cropped/virat_kohli\\virat_kohli311.png',
#   './dataset/cropped/virat_kohli\\virat_kohli312.png',
#   './dataset/cropped/virat_kohli\\virat_kohli313.png',
#   './dataset/cropped/virat_kohli\\virat_kohli314.png',
#   './dataset/cropped/virat_kohli\\virat_kohli315.png',
#   './dataset/cropped/virat_kohli\\virat_kohli316.png',
#   './dataset/cropped/virat_kohli\\virat_kohli318.png',
#   './dataset/cropped/virat_kohli\\virat_kohli32.png',
#   './dataset/cropped/virat_kohli\\virat_kohli320.png',
#   './dataset/cropped/virat_kohli\\virat_kohli321.png',
#   './dataset/cropped/virat_kohli\\virat_kohli322.png',
#   './dataset/cropped/virat_kohli\\virat_kohli323.png',
#   './dataset/cropped/virat_kohli\\virat_kohli324.png',
#   './dataset/cropped/virat_kohli\\virat_kohli325.png',
#   './dataset/cropped/virat_kohli\\virat_kohli326.png',
#   './dataset/cropped/virat_kohli\\virat_kohli327.png',
#   './dataset/cropped/virat_kohli\\virat_kohli328.png',
#   './dataset/cropped/virat_kohli\\virat_kohli329.png',
#   './dataset/cropped/virat_kohli\\virat_kohli330.png',
#   './dataset/cropped/virat_kohli\\virat_kohli331.png',
#   './dataset/cropped/virat_kohli\\virat_kohli332.png',
#   './dataset/cropped/virat_kohli\\virat_kohli333.png',
#   './dataset/cropped/virat_kohli\\virat_kohli334.png',
#   './dataset/cropped/virat_kohli\\virat_kohli335.png',
#   './dataset/cropped/virat_kohli\\virat_kohli336.png',
#   './dataset/cropped/virat_kohli\\virat_kohli337.png',
#   './dataset/cropped/virat_kohli\\virat_kohli338.png',
#   './dataset/cropped/virat_kohli\\virat_kohli339.png',
#   './dataset/cropped/virat_kohli\\virat_kohli34.png',
#   './dataset/cropped/virat_kohli\\virat_kohli340.png',
#   './dataset/cropped/virat_kohli\\virat_kohli341.png',
#   './dataset/cropped/virat_kohli\\virat_kohli342.png',
#   './dataset/cropped/virat_kohli\\virat_kohli343.png',
#   './dataset/cropped/virat_kohli\\virat_kohli344.png',
#   './dataset/cropped/virat_kohli\\virat_kohli345.png',
#   './dataset/cropped/virat_kohli\\virat_kohli346.png',
#   './dataset/cropped/virat_kohli\\virat_kohli347.png',
#   './dataset/cropped/virat_kohli\\virat_kohli348.png',
#   './dataset/cropped/virat_kohli\\virat_kohli349.png',
#   './dataset/cropped/virat_kohli\\virat_kohli35.png',
#   './dataset/cropped/virat_kohli\\virat_kohli350.png',
#   './dataset/cropped/virat_kohli\\virat_kohli351.png',
#   './dataset/cropped/virat_kohli\\virat_kohli352.png',
#   './dataset/cropped/virat_kohli\\virat_kohli353.png',
#   './dataset/cropped/virat_kohli\\virat_kohli354.png',
#   './dataset/cropped/virat_kohli\\virat_kohli355.png',
#   './dataset/cropped/virat_kohli\\virat_kohli356.png',
#   './dataset/cropped/virat_kohli\\virat_kohli357.png',
#   './dataset/cropped/virat_kohli\\virat_kohli358.png',
#   './dataset/cropped/virat_kohli\\virat_kohli359.png',
#   './dataset/cropped/virat_kohli\\virat_kohli36.png',
#   './dataset/cropped/virat_kohli\\virat_kohli360.png',
#   './dataset/cropped/virat_kohli\\virat_kohli361.png',
#   './dataset/cropped/virat_kohli\\virat_kohli363.png',
#   './dataset/cropped/virat_kohli\\virat_kohli365.png',
#   './dataset/cropped/virat_kohli\\virat_kohli366.png',
#   './dataset/cropped/virat_kohli\\virat_kohli368.png',
#   './dataset/cropped/virat_kohli\\virat_kohli369.png',
#   './dataset/cropped/virat_kohli\\virat_kohli37.png',
#   './dataset/cropped/virat_kohli\\virat_kohli370.png',
#   './dataset/cropped/virat_kohli\\virat_kohli371.png',
#   './dataset/cropped/virat_kohli\\virat_kohli372.png',
#   './dataset/cropped/virat_kohli\\virat_kohli374.png',
#   './dataset/cropped/virat_kohli\\virat_kohli375.png',
#   './dataset/cropped/virat_kohli\\virat_kohli377.png',
#   './dataset/cropped/virat_kohli\\virat_kohli378.png',
#   './dataset/cropped/virat_kohli\\virat_kohli379.png',
#   './dataset/cropped/virat_kohli\\virat_kohli38.png',
#   './dataset/cropped/virat_kohli\\virat_kohli380.png',
#   './dataset/cropped/virat_kohli\\virat_kohli381.png',
#   './dataset/cropped/virat_kohli\\virat_kohli382.png',
#   './dataset/cropped/virat_kohli\\virat_kohli383.png',
#   './dataset/cropped/virat_kohli\\virat_kohli384.png',
#   './dataset/cropped/virat_kohli\\virat_kohli385.png',
#   './dataset/cropped/virat_kohli\\virat_kohli386.png',
#   './dataset/cropped/virat_kohli\\virat_kohli387.png',
#   './dataset/cropped/virat_kohli\\virat_kohli388.png',
#   './dataset/cropped/virat_kohli\\virat_kohli39.png',
#   './dataset/cropped/virat_kohli\\virat_kohli390.png',
#   './dataset/cropped/virat_kohli\\virat_kohli391.png',
#   './dataset/cropped/virat_kohli\\virat_kohli392.png',
#   './dataset/cropped/virat_kohli\\virat_kohli393.png',
#   './dataset/cropped/virat_kohli\\virat_kohli394.png',
#   './dataset/cropped/virat_kohli\\virat_kohli395.png',
#   './dataset/cropped/virat_kohli\\virat_kohli396.png',
#   './dataset/cropped/virat_kohli\\virat_kohli397.png',
#   './dataset/cropped/virat_kohli\\virat_kohli398.png',
#   './dataset/cropped/virat_kohli\\virat_kohli399.png',
#   './dataset/cropped/virat_kohli\\virat_kohli4.png',
#   './dataset/cropped/virat_kohli\\virat_kohli40.png',
#   './dataset/cropped/virat_kohli\\virat_kohli400.png',
#   './dataset/cropped/virat_kohli\\virat_kohli402.png',
#   './dataset/cropped/virat_kohli\\virat_kohli403.png',
#   './dataset/cropped/virat_kohli\\virat_kohli404.png',
#   './dataset/cropped/virat_kohli\\virat_kohli405.png',
#   './dataset/cropped/virat_kohli\\virat_kohli406.png',
#   './dataset/cropped/virat_kohli\\virat_kohli407.png',
#   './dataset/cropped/virat_kohli\\virat_kohli408.png',
#   './dataset/cropped/virat_kohli\\virat_kohli409.png',
#   './dataset/cropped/virat_kohli\\virat_kohli41.png',
#   './dataset/cropped/virat_kohli\\virat_kohli410.png',
#   './dataset/cropped/virat_kohli\\virat_kohli411.png',
#   './dataset/cropped/virat_kohli\\virat_kohli412.png',
#   './dataset/cropped/virat_kohli\\virat_kohli414.png',
#   './dataset/cropped/virat_kohli\\virat_kohli415.png',
#   './dataset/cropped/virat_kohli\\virat_kohli417.png',
#   './dataset/cropped/virat_kohli\\virat_kohli418.png',
#   './dataset/cropped/virat_kohli\\virat_kohli419.png',
#   './dataset/cropped/virat_kohli\\virat_kohli42.png',
#   './dataset/cropped/virat_kohli\\virat_kohli420.png',
#   './dataset/cropped/virat_kohli\\virat_kohli421.png',
#   './dataset/cropped/virat_kohli\\virat_kohli422.png',
#   './dataset/cropped/virat_kohli\\virat_kohli423.png',
#   './dataset/cropped/virat_kohli\\virat_kohli424.png',
#   './dataset/cropped/virat_kohli\\virat_kohli425.png',
#   './dataset/cropped/virat_kohli\\virat_kohli426.png',
#   './dataset/cropped/virat_kohli\\virat_kohli427.png',
#   './dataset/cropped/virat_kohli\\virat_kohli428.png',
#   './dataset/cropped/virat_kohli\\virat_kohli429.png',
#   './dataset/cropped/virat_kohli\\virat_kohli43.png',
#   './dataset/cropped/virat_kohli\\virat_kohli430.png',
#   './dataset/cropped/virat_kohli\\virat_kohli431.png',
#   './dataset/cropped/virat_kohli\\virat_kohli432.png',
#   './dataset/cropped/virat_kohli\\virat_kohli433.png',
#   './dataset/cropped/virat_kohli\\virat_kohli434.png',
#   './dataset/cropped/virat_kohli\\virat_kohli435.png',
#   './dataset/cropped/virat_kohli\\virat_kohli436.png',
#   './dataset/cropped/virat_kohli\\virat_kohli437.png',
#   './dataset/cropped/virat_kohli\\virat_kohli438.png',
#   './dataset/cropped/virat_kohli\\virat_kohli439.png',
#   './dataset/cropped/virat_kohli\\virat_kohli44.png',
#   './dataset/cropped/virat_kohli\\virat_kohli440.png',
#   './dataset/cropped/virat_kohli\\virat_kohli441.png',
#   './dataset/cropped/virat_kohli\\virat_kohli442.png',
#   './dataset/cropped/virat_kohli\\virat_kohli445.png',
#   './dataset/cropped/virat_kohli\\virat_kohli446.png',
#   './dataset/cropped/virat_kohli\\virat_kohli448.png',
#   './dataset/cropped/virat_kohli\\virat_kohli449.png',
#   './dataset/cropped/virat_kohli\\virat_kohli45.png',
#   './dataset/cropped/virat_kohli\\virat_kohli450.png',
#   './dataset/cropped/virat_kohli\\virat_kohli451.png',
#   './dataset/cropped/virat_kohli\\virat_kohli452.png',
#   './dataset/cropped/virat_kohli\\virat_kohli453.png',
#   './dataset/cropped/virat_kohli\\virat_kohli454.png',
#   './dataset/cropped/virat_kohli\\virat_kohli455.png',
#   './dataset/cropped/virat_kohli\\virat_kohli456.png',
#   './dataset/cropped/virat_kohli\\virat_kohli457.png',
#   './dataset/cropped/virat_kohli\\virat_kohli458.png',
#   './dataset/cropped/virat_kohli\\virat_kohli459.png',
#   './dataset/cropped/virat_kohli\\virat_kohli460.png',
#   './dataset/cropped/virat_kohli\\virat_kohli461.png',
#   './dataset/cropped/virat_kohli\\virat_kohli462.png',
#   './dataset/cropped/virat_kohli\\virat_kohli463.png',
#   './dataset/cropped/virat_kohli\\virat_kohli464.png',
#   './dataset/cropped/virat_kohli\\virat_kohli465.png',
#   './dataset/cropped/virat_kohli\\virat_kohli466.png',
#   './dataset/cropped/virat_kohli\\virat_kohli467.png',
#   './dataset/cropped/virat_kohli\\virat_kohli468.png',
#   './dataset/cropped/virat_kohli\\virat_kohli469.png',
#   './dataset/cropped/virat_kohli\\virat_kohli47.png',
#   './dataset/cropped/virat_kohli\\virat_kohli470.png',
#   './dataset/cropped/virat_kohli\\virat_kohli472.png',
#   './dataset/cropped/virat_kohli\\virat_kohli474.png',
#   './dataset/cropped/virat_kohli\\virat_kohli475.png',
#   './dataset/cropped/virat_kohli\\virat_kohli476.png',
#   './dataset/cropped/virat_kohli\\virat_kohli477.png',
#   './dataset/cropped/virat_kohli\\virat_kohli478.png',
#   './dataset/cropped/virat_kohli\\virat_kohli479.png',
#   './dataset/cropped/virat_kohli\\virat_kohli480.png',
#   './dataset/cropped/virat_kohli\\virat_kohli482.png',
#   './dataset/cropped/virat_kohli\\virat_kohli483.png',
#   './dataset/cropped/virat_kohli\\virat_kohli484.png',
#   './dataset/cropped/virat_kohli\\virat_kohli485.png',
#   './dataset/cropped/virat_kohli\\virat_kohli486.png',
#   './dataset/cropped/virat_kohli\\virat_kohli487.png',
#   './dataset/cropped/virat_kohli\\virat_kohli488.png',
#   './dataset/cropped/virat_kohli\\virat_kohli49.png',
#   './dataset/cropped/virat_kohli\\virat_kohli490.png',
#   './dataset/cropped/virat_kohli\\virat_kohli491.png',
#   './dataset/cropped/virat_kohli\\virat_kohli492.png',
#   './dataset/cropped/virat_kohli\\virat_kohli493.png',
#   './dataset/cropped/virat_kohli\\virat_kohli494.png',
#   './dataset/cropped/virat_kohli\\virat_kohli495.png',
#   './dataset/cropped/virat_kohli\\virat_kohli496.png',
#   './dataset/cropped/virat_kohli\\virat_kohli497.png',
#   './dataset/cropped/virat_kohli\\virat_kohli498.png',
#   './dataset/cropped/virat_kohli\\virat_kohli499.png',
#   './dataset/cropped/virat_kohli\\virat_kohli50.png',
#   './dataset/cropped/virat_kohli\\virat_kohli500.png',
#   './dataset/cropped/virat_kohli\\virat_kohli501.png',
#   './dataset/cropped/virat_kohli\\virat_kohli502.png',
#   './dataset/cropped/virat_kohli\\virat_kohli503.png',
#   './dataset/cropped/virat_kohli\\virat_kohli504.png',
#   './dataset/cropped/virat_kohli\\virat_kohli505.png',
#   './dataset/cropped/virat_kohli\\virat_kohli506.png',
#   './dataset/cropped/virat_kohli\\virat_kohli508.png',
#   './dataset/cropped/virat_kohli\\virat_kohli509.png',
#   './dataset/cropped/virat_kohli\\virat_kohli51.png',
#   './dataset/cropped/virat_kohli\\virat_kohli510.png',
#   './dataset/cropped/virat_kohli\\virat_kohli511.png',
#   './dataset/cropped/virat_kohli\\virat_kohli513.png',
#   './dataset/cropped/virat_kohli\\virat_kohli514.png',
#   './dataset/cropped/virat_kohli\\virat_kohli515.png',
#   './dataset/cropped/virat_kohli\\virat_kohli516.png',
#   './dataset/cropped/virat_kohli\\virat_kohli517.png',
#   './dataset/cropped/virat_kohli\\virat_kohli518.png',
#   './dataset/cropped/virat_kohli\\virat_kohli520.png',
#   './dataset/cropped/virat_kohli\\virat_kohli521.png',
#   './dataset/cropped/virat_kohli\\virat_kohli522.png',
#   './dataset/cropped/virat_kohli\\virat_kohli523.png',
#   './dataset/cropped/virat_kohli\\virat_kohli525.png',
#   './dataset/cropped/virat_kohli\\virat_kohli526.png',
#   './dataset/cropped/virat_kohli\\virat_kohli527.png',
#   './dataset/cropped/virat_kohli\\virat_kohli528.png',
#   './dataset/cropped/virat_kohli\\virat_kohli529.png',
#   './dataset/cropped/virat_kohli\\virat_kohli532.png',
#   './dataset/cropped/virat_kohli\\virat_kohli533.png',
#   './dataset/cropped/virat_kohli\\virat_kohli534.png',
#   './dataset/cropped/virat_kohli\\virat_kohli535.png',
#   './dataset/cropped/virat_kohli\\virat_kohli538.png',
#   './dataset/cropped/virat_kohli\\virat_kohli539.png',
#   './dataset/cropped/virat_kohli\\virat_kohli54.png',
#   './dataset/cropped/virat_kohli\\virat_kohli540.png',
#   './dataset/cropped/virat_kohli\\virat_kohli543.png',
#   './dataset/cropped/virat_kohli\\virat_kohli545.png',
#   './dataset/cropped/virat_kohli\\virat_kohli546.png',
#   './dataset/cropped/virat_kohli\\virat_kohli547.png',
#   './dataset/cropped/virat_kohli\\virat_kohli549.png',
#   './dataset/cropped/virat_kohli\\virat_kohli551.png',
#   './dataset/cropped/virat_kohli\\virat_kohli553.png',
#   './dataset/cropped/virat_kohli\\virat_kohli554.png',
#   './dataset/cropped/virat_kohli\\virat_kohli56.png',
#   './dataset/cropped/virat_kohli\\virat_kohli57.png',
#   './dataset/cropped/virat_kohli\\virat_kohli58.png',
#   './dataset/cropped/virat_kohli\\virat_kohli59.png',
#   './dataset/cropped/virat_kohli\\virat_kohli60.png',
#   './dataset/cropped/virat_kohli\\virat_kohli61.png',
#   './dataset/cropped/virat_kohli\\virat_kohli64.png',
#   './dataset/cropped/virat_kohli\\virat_kohli65.png',
#   './dataset/cropped/virat_kohli\\virat_kohli66.png',
#   './dataset/cropped/virat_kohli\\virat_kohli67.png',
#   './dataset/cropped/virat_kohli\\virat_kohli68.png',
#   './dataset/cropped/virat_kohli\\virat_kohli69.png',
#   './dataset/cropped/virat_kohli\\virat_kohli71.png',
#   './dataset/cropped/virat_kohli\\virat_kohli73.png',
#   './dataset/cropped/virat_kohli\\virat_kohli75.png',
#   './dataset/cropped/virat_kohli\\virat_kohli78.png',
#   './dataset/cropped/virat_kohli\\virat_kohli79.png',
#   './dataset/cropped/virat_kohli\\virat_kohli80.png',
#   './dataset/cropped/virat_kohli\\virat_kohli82.png',
#   './dataset/cropped/virat_kohli\\virat_kohli83.png',
#   './dataset/cropped/virat_kohli\\virat_kohli84.png',
#   './dataset/cropped/virat_kohli\\virat_kohli85.png',
#   './dataset/cropped/virat_kohli\\virat_kohli86.png',
#   './dataset/cropped/virat_kohli\\virat_kohli87.png',
#   './dataset/cropped/virat_kohli\\virat_kohli88.png',
#   './dataset/cropped/virat_kohli\\virat_kohli89.png',
#   './dataset/cropped/virat_kohli\\virat_kohli9.png',
#   './dataset/cropped/virat_kohli\\virat_kohli90.png',
#   './dataset/cropped/virat_kohli\\virat_kohli92.png',
#   './dataset/cropped/virat_kohli\\virat_kohli93.png',
#   './dataset/cropped/virat_kohli\\virat_kohli95.png',
#   './dataset/cropped/virat_kohli\\virat_kohli96.png',
#   './dataset/cropped/virat_kohli\\virat_kohli97.png',
#   './dataset/cropped/virat_kohli\\virat_kohli98.png',
#   './dataset/cropped/virat_kohli\\virat_kohli99.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'akshay_kumar': 0,
#  'alia_bhatt': 1,
#  'amitabh_bachchan': 2,
#  'deepika_padukone': 3,
#  'kiara_advani': 4,
#  'm_s_dhoni': 5,
#  'p_v_sindhu': 6,
#  'ranveer_singh': 7,
#  'rashmika_mandana': 8,
#  'virat_kohli': 9}

# %% [markdown]
# ### Images in cropped folder can be used for model training. We will use these raw images along with wavelet transformed images to train our classifier. Let's prepare X and y now

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[179],
#        [174],
#        [188],
#        ...,
#        [ 12],
#        [ 11],
#        [  1]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (2788, 4096)

# %% [markdown]
# ### Data cleaning process is done. Now we are ready to train our model

# %% [markdown]
# We will use SVM with rbf kernel tuned  with heuristic finetuning

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.7546628407460545

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.70      0.74        44
#            1       0.67      0.68      0.67        91
#            2       0.94      0.84      0.89        38
#            3       0.73      0.83      0.78       141
#            4       0.64      0.75      0.69        76
#            5       0.65      0.61      0.63        18
#            6       0.81      0.61      0.70        49
#            7       0.76      0.50      0.60        44
#            8       0.75      0.65      0.69        77
#            9       0.87      0.96      0.91       119
#
#     accuracy                           0.75       697
#    macro avg       0.76      0.71      0.73       697
# weighted avg       0.76      0.75      0.75       697

# %% [markdown]
# ### Let's use GridSearch to try out different models with different paramets. Goal is to come up with best modle with best fine tuned parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.755628
# 1        random_forest    0.465329
# 2  logistic_regression    0.701110
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.7474892395982783

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.5164992826398852

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.7144906743185079

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 28,   2,   0,   2,   1,   4,   2,   3,   0,   2],
#        [  2,  69,   0,   6,   7,   1,   0,   0,   6,   0],
#        [  2,   0,  31,   1,   0,   1,   0,   1,   2,   0],
#        [  4,   9,   1, 106,   7,   2,   4,   1,   6,   1],
#        [  1,  10,   0,   8,  54,   1,   0,   0,   2,   0],
#        [  0,   0,   0,   0,   0,  13,   0,   3,   1,   1],
#        [  1,   3,   1,   7,   2,   0,  32,   1,   1,   1],
#        [  3,   2,   0,   4,   1,   1,   2,  22,   0,   9],
#        [  2,   8,   0,   9,   6,   0,   0,   1,  51,   0],
#        [  1,   1,   0,   0,   0,   0,   1,   1,   0, 115]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'akshay_kumar': 0,
#  'alia_bhatt': 1,
#  'amitabh_bachchan': 2,
#  'deepika_padukone': 3,
#  'kiara_advani': 4,
#  'm_s_dhoni': 5,
#  'p_v_sindhu': 6,
#  'ranveer_singh': 7,
#  'rashmika_mandana': 8,
#  'virat_kohli': 9}

# %% [markdown]
# ### Save the trained model

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\dinesh\anaconda3\lib\site-packages (1.1.0)
# ['saved_model.pkl']

# %% [markdown]
# ### Save class dictionary

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
